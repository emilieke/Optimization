# %% [markdown]
# # Objective function:
# $$\min \sum_{k=1}^K\sum_{j=1}^{J}\left(A_j v_{jk}+B_{j}p_{jk}+C_{j}y_{jk}+E_{j}z_{jk}\right)$$
#
# where:
# <li> $C_j$: startup costs of unit $j$
# <li> $y_{jk}$: binary variable equal to 1 if unit $j$ is startup in period $k$ (0 otherwise).
# <li> $E_j$: shutdown costs of unit $j$
# <li> $z_{jk}$: binary variable equal to 1 if unit $j$ is shutdown in period $k$ (0 otherwise).
# <li> $A_j$: fixed costs of unit $j$
# <li> $v_{jk}$: binary variable equal to 1 if unit $j$ is online during period $k$ (0 otherwise).
# <li> $B_j$: variable costs of unit $j$
# <li> $p_{jk}$: continuous variable: output power of unit $j$ during period $k$.
#
# # Constraints
#
# <li> Technical upper and lower output limits:
# $$\underline{P}_{j}v_{jk} \leq p_{jk} \leq \overline{P}_{j}v_{jk}\quad \forall j,k$$
# <li> Rampup limits:
# $$p_{j(k+1)}-p_{jk}\leq S_j\quad \forall j,k<K$$
#
# *additionally: $p_{j1}-P_{j}^{0}\leq S_j\quad \forall j$
# <li> Rampdown limits:
# $$p_{jk}-p_{j(k+1)}\leq T_j\quad \forall j,k<K$$
# *additionally: $P_{j}^{0}-p_{j1}\leq T_j\quad \forall j$
#
#
# <li> Any unit that is online cannot be started up, any unit that is offline cannot be shut down:
# $$y_{jk}-z_{jk}=v_{jk}-v_{j(k-1)} \quad \forall j,k>1$$
# *For the first period: $y_{j1}-z_{j1}=v_{j1}-V_j^0$, where $V_j^0$ initial status $t=0$
# <li> Power demand should be satisfied:
# $$\sum_{j=1}^{J}p_{jk}=D_{k}\quad \forall k$$
# <li> Security reserve requirements $R_k$:
# $$\sum_{j=1}^J \overline{P}_j v_{jk}\geq D_{k}+R_k\quad \forall k$$

# %%
#Self sheduling of a thermal generator
from pyomo.environ import *
opt = SolverFactory("glpk")
from pyomo.opt import SolverFactory

model = AbstractModel()

#definition of sets
model.n = Param(within=NonNegativeIntegers)#number of time units J
model.m = Param(within=NonNegativeIntegers)#number of time periods K
model.J = RangeSet(1,model.n)
model.K = RangeSet(1,model.m)

#model parameters
model.C = Param(model.J,within=NonNegativeReals)#startup  cost
model.E = Param(model.J,within=NonNegativeReals)#shutdown cost
model.A = Param(model.J,within=NonNegativeReals)#fixed production cost
model.B = Param(model.J,within=NonNegativeReals)#variable production cost

model.P_max = Param(model.J,within=NonNegativeReals)#maximum production per unit
model.P_min = Param(model.J,within=NonNegativeReals)#minimun production per unit
model.P_0 = Param(model.J,within=NonNegativeReals) #initial production at t=0
model.V_0 = Param(model.J,within=Binary) #initial status at t=0, binary variables required

model.S = Param(model.J,within=NonNegativeReals)#ramp up limit
model.T = Param(model.J,within=NonNegativeReals)#ramp down limit

model.D = Param(model.K,within=NonNegativeReals,mutable=True)#demand for each period of time
model.R = Param(model.K,within=NonNegativeReals)#reserve for each period of time

#variables: continuous
model.p = Var(model.J, model.K) #production for each unit and period of time

model.y = Var(model.J, model.K, domain=Binary)
model.z = Var(model.J, model.K, domain=Binary)
model.v = Var(model.J, model.K, domain=Binary)

#objective function
def Obj_rule(model):
	return ##################################################################
model.Obj = Objective(rule=Obj_rule, sense=minimize)

#constraint max prod
def max_prod(model, j, k): 
	return ##################################################################
model.max_prod_cons = Constraint(model.J, model.K, rule=max_prod)

#constraint min prod
def min_prod(model, j, k): 
	return ##################################################################
model.min_prod_cons = Constraint(model.J, model.K, rule=min_prod)


#constraint ramp_up
def ramp_up(model, j, k): 
	if k < model.m:
		return ##################################################################] 
	else:
		return ##################################################################
model.ramp_up_cons = Constraint(model.J, model.K, rule=ramp_up)

#constraint ramp_up_0
def ramp_up_0(model, j, k): 
	if k == 1:
		return ##################################################################
	else:
		return ##################################################################
model.ramp_up_0_cons = Constraint(model.J, model.K, rule=ramp_up_0)

#constraint ramp_down
def ramp_down(model, j, k): 
	if k < model.m:
		return ##################################################################
	else:
		return ##################################################################
model.ramp_down_cons = Constraint(model.J, model.K, rule=ramp_down)

#constraint ramp_down_0
def ramp_down_0(model, j, k): 
	if k == 1:
		return ##################################################################
	else:
		return ##################################################################
model.ramp_down_0_cons = Constraint(model.J, model.K, rule=ramp_down_0)


#constraint binary variables
def bin_cons(model, j, k): 
	if k > 1:
		return ##################################################################
	else:
		return ##################################################################] 
model.bin_cons_cons = Constraint(model.J, model.K, rule=bin_cons)

#Demand balance
def demand(model, k): 
	return ##################################################################
model.demand_cons = Constraint(model.K, rule=demand)

#reserve requirements
def reserve(model, k): 
	return ##################################################################  
model.reserve_cons = Constraint(model.K, rule=reserve)

# %%
# %%writefile power_schedule.dat
#
#
# param n := 3
# ;
#
# param m := 3
# ;
#
#
# param E :=
# 1 0.5
# 2 0.3
# 3 1
# ;
#
# param A :=
# 1 5
# 2 7
# 3 6
# ;
#
# param B :=
# 1 0.1
# 2 0.125
# 3 0.150
# ;
#
# param C :=
# 1 20
# 2 18
# 3 5
# ;
#
# param P_max :=
# 1 350
# 2 200
# 3 140
# ;
#
# param P_min :=
# 1 50
# 2 80
# 3 40
# ;
#
# param P_0:=
# 1 0
# 2 0
# 3 0
# ;
#
# param V_0:=
# 1 0
# 2 0
# 3 0
# ;
#
# param S :=
# 1 200
# 2 100
# 3 100
# ;
#
# param T :=
# 1 300
# 2 150
# 3 100
# ;
#
# param D :=
# 1 150
# 2 500
# 3 400
# ;
#
# param R :=
# 1 15
# 2 50
# 3 40
# ;
# Out:
# Overwriting power_schedule.dat

# %%
instance = model.create_instance('power_schedule.dat')
instance.pprint()
results = opt.solve(instance)
print(results)
# Out:
# WARNING: DEPRECATION WARNING: the Model.create() method is deprecated.  Call
# 	Model.create_instance() to create a concrete instance from an abstract
# 	model.  You do not need to call Model.create() for a concrete model.
# 11 Set Declarations
#     bin_cons_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     max_prod_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     min_prod_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     p_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     ramp_down_0_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     ramp_down_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     ramp_up_0_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     ramp_up_cons_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     v_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     y_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#     z_index : Dim=0, Dimen=2, Size=9, Domain=None, Ordered=True, Bounds=None
#         Virtual
#
# 2 RangeSet Declarations
#     J : Dim=0, Dimen=1, Size=3, Domain=Integers, Ordered=True, Bounds=(1, 3)
#         Virtual
#     K : Dim=0, Dimen=1, Size=3, Domain=Integers, Ordered=True, Bounds=(1, 3)
#         Virtual
#
# 14 Param Declarations
#     A : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :     5
#           2 :     7
#           3 :     6
#     B : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :   0.1
#           2 : 0.125
#           3 :  0.15
#     C : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :    20
#           2 :    18
#           3 :     5
#     D : Size=3, Index=K, Domain=NonNegativeReals, Default=None, Mutable=True
#         Key : Value
#           1 :   150
#           2 :   500
#           3 :   400
#     E : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :   0.5
#           2 :   0.3
#           3 :     1
#     P_0 : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :     0
#           2 :     0
#           3 :     0
#     P_max : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :   350
#           2 :   200
#           3 :   140
#     P_min : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :    50
#           2 :    80
#           3 :    40
#     R : Size=3, Index=K, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :    15
#           2 :    50
#           3 :    40
#     S : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :   200
#           2 :   100
#           3 :   100
#     T : Size=3, Index=J, Domain=NonNegativeReals, Default=None, Mutable=False
#         Key : Value
#           1 :   300
#           2 :   150
#           3 :   100
#     V_0 : Size=3, Index=J, Domain=Binary, Default=None, Mutable=False
#         Key : Value
#           1 :     0
#           2 :     0
#           3 :     0
#     m : Size=1, Index=None, Domain=NonNegativeIntegers, Default=None, Mutable=False
#         Key  : Value
#         None :     3
#     n : Size=1, Index=None, Domain=NonNegativeIntegers, Default=None, Mutable=False
#         Key  : Value
#         None :     3
#
# 4 Var Declarations
#     p : Size=9, Index=p_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :  None :  None :  None : False :  True :  Reals
#         (1, 2) :  None :  None :  None : False :  True :  Reals
#         (1, 3) :  None :  None :  None : False :  True :  Reals
#         (2, 1) :  None :  None :  None : False :  True :  Reals
#         (2, 2) :  None :  None :  None : False :  True :  Reals
#         (2, 3) :  None :  None :  None : False :  True :  Reals
#         (3, 1) :  None :  None :  None : False :  True :  Reals
#         (3, 2) :  None :  None :  None : False :  True :  Reals
#         (3, 3) :  None :  None :  None : False :  True :  Reals
#     v : Size=9, Index=v_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :     0 :  None :     1 : False :  True : Binary
#         (1, 2) :     0 :  None :     1 : False :  True : Binary
#         (1, 3) :     0 :  None :     1 : False :  True : Binary
#         (2, 1) :     0 :  None :     1 : False :  True : Binary
#         (2, 2) :     0 :  None :     1 : False :  True : Binary
#         (2, 3) :     0 :  None :     1 : False :  True : Binary
#         (3, 1) :     0 :  None :     1 : False :  True : Binary
#         (3, 2) :     0 :  None :     1 : False :  True : Binary
#         (3, 3) :     0 :  None :     1 : False :  True : Binary
#     y : Size=9, Index=y_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :     0 :  None :     1 : False :  True : Binary
#         (1, 2) :     0 :  None :     1 : False :  True : Binary
#         (1, 3) :     0 :  None :     1 : False :  True : Binary
#         (2, 1) :     0 :  None :     1 : False :  True : Binary
#         (2, 2) :     0 :  None :     1 : False :  True : Binary
#         (2, 3) :     0 :  None :     1 : False :  True : Binary
#         (3, 1) :     0 :  None :     1 : False :  True : Binary
#         (3, 2) :     0 :  None :     1 : False :  True : Binary
#         (3, 3) :     0 :  None :     1 : False :  True : Binary
#     z : Size=9, Index=z_index
#         Key    : Lower : Value : Upper : Fixed : Stale : Domain
#         (1, 1) :     0 :  None :     1 : False :  True : Binary
#         (1, 2) :     0 :  None :     1 : False :  True : Binary
#         (1, 3) :     0 :  None :     1 : False :  True : Binary
#         (2, 1) :     0 :  None :     1 : False :  True : Binary
#         (2, 2) :     0 :  None :     1 : False :  True : Binary
#         (2, 3) :     0 :  None :     1 : False :  True : Binary
#         (3, 1) :     0 :  None :     1 : False :  True : Binary
#         (3, 2) :     0 :  None :     1 : False :  True : Binary
#         (3, 3) :     0 :  None :     1 : False :  True : Binary
#
# 1 Objective Declarations
#     Obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 5*v[1,1] + 0.1*p[1,1] + 20*y[1,1] + 0.5*z[1,1] + 7*v[2,1] + 0.125*p[2,1] + 18*y[2,1] + 0.3*z[2,1] + 6*v[3,1] + 0.15*p[3,1] + 5*y[3,1] + z[3,1] + 5*v[1,2] + 0.1*p[1,2] + 20*y[1,2] + 0.5*z[1,2] + 7*v[2,2] + 0.125*p[2,2] + 18*y[2,2] + 0.3*z[2,2] + 6*v[3,2] + 0.15*p[3,2] + 5*y[3,2] + z[3,2] + 5*v[1,3] + 0.1*p[1,3] + 20*y[1,3] + 0.5*z[1,3] + 7*v[2,3] + 0.125*p[2,3] + 18*y[2,3] + 0.3*z[2,3] + 6*v[3,3] + 0.15*p[3,3] + 5*y[3,3] + z[3,3]
#
# 9 Constraint Declarations
#     bin_cons_cons : Size=9, Index=bin_cons_cons_index, Active=True
#         Key    : Lower : Body                              : Upper : Active
#         (1, 1) :   0.0 :          y[1,1] - z[1,1] - v[1,1] :   0.0 :   True
#         (1, 2) :   0.0 : y[1,2] - z[1,2] - v[1,2] + v[1,1] :   0.0 :   True
#         (1, 3) :   0.0 : y[1,3] - z[1,3] - v[1,3] + v[1,2] :   0.0 :   True
#         (2, 1) :   0.0 :          y[2,1] - z[2,1] - v[2,1] :   0.0 :   True
#         (2, 2) :   0.0 : y[2,2] - z[2,2] - v[2,2] + v[2,1] :   0.0 :   True
#         (2, 3) :   0.0 : y[2,3] - z[2,3] - v[2,3] + v[2,2] :   0.0 :   True
#         (3, 1) :   0.0 :          y[3,1] - z[3,1] - v[3,1] :   0.0 :   True
#         (3, 2) :   0.0 : y[3,2] - z[3,2] - v[3,2] + v[3,1] :   0.0 :   True
#         (3, 3) :   0.0 : y[3,3] - z[3,3] - v[3,3] + v[3,2] :   0.0 :   True
#     demand_cons : Size=3, Index=K, Active=True
#         Key : Lower : Body                     : Upper : Active
#           1 :  D[1] : p[1,1] + p[2,1] + p[3,1] :  D[1] :   True
#           2 :  D[2] : p[1,2] + p[2,2] + p[3,2] :  D[2] :   True
#           3 :  D[3] : p[1,3] + p[2,3] + p[3,3] :  D[3] :   True
#     max_prod_cons : Size=9, Index=max_prod_cons_index, Active=True
#         Key    : Lower : Body                : Upper : Active
#         (1, 1) :  -Inf : p[1,1] - 350*v[1,1] :   0.0 :   True
#         (1, 2) :  -Inf : p[1,2] - 350*v[1,2] :   0.0 :   True
#         (1, 3) :  -Inf : p[1,3] - 350*v[1,3] :   0.0 :   True
#         (2, 1) :  -Inf : p[2,1] - 200*v[2,1] :   0.0 :   True
#         (2, 2) :  -Inf : p[2,2] - 200*v[2,2] :   0.0 :   True
#         (2, 3) :  -Inf : p[2,3] - 200*v[2,3] :   0.0 :   True
#         (3, 1) :  -Inf : p[3,1] - 140*v[3,1] :   0.0 :   True
#         (3, 2) :  -Inf : p[3,2] - 140*v[3,2] :   0.0 :   True
#         (3, 3) :  -Inf : p[3,3] - 140*v[3,3] :   0.0 :   True
#     min_prod_cons : Size=9, Index=min_prod_cons_index, Active=True
#         Key    : Lower : Body               : Upper : Active
#         (1, 1) :  -Inf : 50*v[1,1] - p[1,1] :   0.0 :   True
#         (1, 2) :  -Inf : 50*v[1,2] - p[1,2] :   0.0 :   True
#         (1, 3) :  -Inf : 50*v[1,3] - p[1,3] :   0.0 :   True
#         (2, 1) :  -Inf : 80*v[2,1] - p[2,1] :   0.0 :   True
#         (2, 2) :  -Inf : 80*v[2,2] - p[2,2] :   0.0 :   True
#         (2, 3) :  -Inf : 80*v[2,3] - p[2,3] :   0.0 :   True
#         (3, 1) :  -Inf : 40*v[3,1] - p[3,1] :   0.0 :   True
#         (3, 2) :  -Inf : 40*v[3,2] - p[3,2] :   0.0 :   True
#         (3, 3) :  -Inf : 40*v[3,3] - p[3,3] :   0.0 :   True
#     ramp_down_0_cons : Size=3, Index=ramp_down_0_cons_index, Active=True
#         Key    : Lower : Body      : Upper : Active
#         (1, 1) :  -Inf :  - p[1,1] : 300.0 :   True
#         (2, 1) :  -Inf :  - p[2,1] : 150.0 :   True
#         (3, 1) :  -Inf :  - p[3,1] : 100.0 :   True
#     ramp_down_cons : Size=6, Index=ramp_down_cons_index, Active=True
#         Key    : Lower : Body            : Upper : Active
#         (1, 1) :  -Inf : p[1,1] - p[1,2] : 300.0 :   True
#         (1, 2) :  -Inf : p[1,2] - p[1,3] : 300.0 :   True
#         (2, 1) :  -Inf : p[2,1] - p[2,2] : 150.0 :   True
#         (2, 2) :  -Inf : p[2,2] - p[2,3] : 150.0 :   True
#         (3, 1) :  -Inf : p[3,1] - p[3,2] : 100.0 :   True
#         (3, 2) :  -Inf : p[3,2] - p[3,3] : 100.0 :   True
#     ramp_up_0_cons : Size=3, Index=ramp_up_0_cons_index, Active=True
#         Key    : Lower : Body   : Upper : Active
#         (1, 1) :  -Inf : p[1,1] : 200.0 :   True
#         (2, 1) :  -Inf : p[2,1] : 100.0 :   True
#         (3, 1) :  -Inf : p[3,1] : 100.0 :   True
#     ramp_up_cons : Size=6, Index=ramp_up_cons_index, Active=True
#         Key    : Lower : Body            : Upper : Active
#         (1, 1) :  -Inf : p[1,2] - p[1,1] : 200.0 :   True
#         (1, 2) :  -Inf : p[1,3] - p[1,2] : 200.0 :   True
#         (2, 1) :  -Inf : p[2,2] - p[2,1] : 100.0 :   True
#         (2, 2) :  -Inf : p[2,3] - p[2,2] : 100.0 :   True
#         (3, 1) :  -Inf : p[3,2] - p[3,1] : 100.0 :   True
#         (3, 2) :  -Inf : p[3,3] - p[3,2] : 100.0 :   True
#     reserve_cons : Size=3, Index=K, Active=True
#         Key : Lower     : Body                                 : Upper : Active
#           1 : 15 + D[1] : 350*v[1,1] + 200*v[2,1] + 140*v[3,1] :  +Inf :   True
#           2 : 50 + D[2] : 350*v[1,2] + 200*v[2,2] + 140*v[3,2] :  +Inf :   True
#           3 : 40 + D[3] : 350*v[1,3] + 200*v[2,3] + 140*v[3,3] :  +Inf :   True
#
# 41 Declarations: n m J K C E A B P_max P_min P_0 V_0 S T D R p_index p y_index y z_index z v_index v Obj max_prod_cons_index max_prod_cons min_prod_cons_index min_prod_cons ramp_up_cons_index ramp_up_cons ramp_up_0_cons_index ramp_up_0_cons ramp_down_cons_index ramp_down_cons ramp_down_0_cons_index ramp_down_0_cons bin_cons_cons_index bin_cons_cons demand_cons reserve_cons
#
# Problem:
# - Name: unknown
#   Lower bound: 189.8
#   Upper bound: 189.8
#   Number of objectives: 1
#   Number of constraints: 52
#   Number of variables: 37
#   Number of nonzeros: 118
#   Sense: minimize
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 3
#       Number of created subproblems: 3
#   Error rc: 0
#   Time: 0.17249488830566406
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
#from coopr.pyomo import value
#from pyomo import value
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
n_iter=500
OF_iter=np.zeros(n_iter)
p_iter=np.zeros(n_iter)
instance = model.create_instance('power_schedule.dat')

cont=0;
for cont in range(0,n_iter):
    ##################################################################
    
plt.plot(range(0,n_iter)+np.ones(n_iter)*50,OF_iter)
# Out:
#   File "<ipython-input-1-74debb4229df>", line 15
#     plt.plot(range(0,n_iter)+np.ones(n_iter)*50,OF_iter)
#       ^
# IndentationError: expected an indented block
